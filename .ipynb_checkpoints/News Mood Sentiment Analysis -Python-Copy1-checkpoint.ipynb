# %%
#Dependencies
import tweepy
import json

# Twitter API Keys
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Search Term
#search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search('instant ink', rpp=100)

print(len(public_tweets))

# View Search Object
# print(public_tweets)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

   # Utilize JSON dumps to generate a pretty-printed json
   # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# 2
# RT @ActuFoot_: Il y a 20 ans jour pour jour et à cet instant, l’équipe de France était sacrée championne du monde ! 🇫🇷 https://t.co/hWc4fgL…
# @innerlightuk Did you subscribe to the HP Instant ink?
# Lvl 150 superboss, Blizzard Brenzinga
#
# Brenzinga Tweet Like casts 150% more effective instant validation in blizzar… https://t.co/aDaB0jw1t9
# Instant Ink Full Stack Web Developer: Blog Search jobs Keyword CategorySelectAdministrationBusiness PlanningCorpora… https://t.co/ygGygq33Vn
# Discover how the HP Instant Ink system works, program requirements, &amp; a list of Instant Ink ready printers.… https://t.co/HwZQ5cU423
# @innerlightuk Hi Mick, Thanks for tweeting. Looks like you have issues with the printer cartridge. Are you getting… https://t.co/wTsWyFUZLV
# Frustrated? How to DISABLE enrollment from the #HP #Instant #Ink #Program https://t.co/yWKh6my099  #printer #ink… https://t.co/Nu4KuKldiN
# ...

# %%
api.
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
tweet['source']
# Out:
# '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>'

# %%
type(tweet)
# Out:
# dict

# %%
for i in tweet:
    print(i)
    print(tweet[i])
    print("------")
# Out:
# created_at
# Thu Jul 12 08:41:27 +0000 2018
# ------
# id
# 1017328068447358976
# ------
# id_str
# 1017328068447358976
# ------
# text
# RT @CanonProPrintUK: Deliver instant dry prints with our advanced ink technology, #CanonUVgel and benefit from improved colour gamut and pr…
# ------
# truncated
# False
# ------
# entities
# {'hashtags': [{'text': 'CanonUVgel', 'indices': [82, 93]}], 'symbols': [], 'user_mentions': [{'screen_name': 'CanonProPrintUK', 'name': 'Canon UK Pro Print', 'id': 15252443, 'id_str': '15252443', 'indices': [3, 19]}], 'urls': []}
# ------
# metadata
# {'iso_language_code': 'en', 'result_type': 'recent'}
# ------
# source
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# ------
# in_reply_to_status_id
# None
# ------
# in_reply_to_status_id_str
# None
# ------
# in_reply_to_user_id
# None
# ------
# in_reply_to_user_id_str
# None
# ------
# in_reply_to_screen_name
# None
# ------
# user
# ...

# %%
tweet['text']
# Out:
# "RT @Julie_C_Hwang: The last article in the special issue on women's support for terrorism in Pakistan by @CChristineFair and Ali Hamza is o…"

# %%
from twitter import *

# %%
# Twitter API Keys
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# %%
twitter = Twitter(auth = OAuth(access_token,
                  access_token_secret,
                  consumer_key,
                  consumer_secret))

# %%
#count=3, until='2012-01-01'
query = twitter.search.tweets(q = "instant ink", count=10000)
print(type(query))
# Out:
# <class 'twitter.api.TwitterDictResponse'>

# %%
test = query['statuses']

# %%
i['screen_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-d6f3ece582a5> in <module>()
# ----> 1 i['screen_name']
#
# KeyError: 'screen_name'

# %%
data_search
# Out:
# {'date': 'Mon Jul 09 13:01:19 +0000 2018',
#  'text': '🔰CHOLLO‼️ 🔎Amazon\n\n🍀 HP Envy 5030 – Impresora Multifunción inalámbrica (Tinta, Wi-Fi, copiar, escanear, 1200 x 1200… https://t.co/fY5IjtJsdH',
#  'user': 'Cholloterapia'}

# %%
data_search = {}
counter=1
for i in test:
    print(counter)
    data_search['text'] = i['text']
    data_search['date'] = i['created_at']
    data_search['user'] = i['user']['screen_name']
    print(i['text'])
    print(i['created_at'])
    print(i['user']['screen_name'])
    print('----------------')
    counter +=1
# Out:
# 1
# Try a FREE Month of HP Instant Ink! #HPMillennials https://t.co/5E6eNJWXWB
# Fri Jul 13 02:16:59 +0000 2018
# abetterlifeblog
# ----------------
# 2
# RT @ActuFoot_: Il y a 20 ans jour pour jour et à cet instant, l’équipe de France était sacrée championne du monde ! 🇫🇷 https://t.co/hWc4fgL…
# Thu Jul 12 20:54:37 +0000 2018
# Jord_Ink
# ----------------
# 3
# @innerlightuk Did you subscribe to the HP Instant ink?
# Thu Jul 12 20:26:21 +0000 2018
# HPSupport
# ----------------
# 4
# Lvl 150 superboss, Blizzard Brenzinga
#
# Brenzinga Tweet Like casts 150% more effective instant validation in blizzar… https://t.co/aDaB0jw1t9
# Thu Jul 12 18:26:48 +0000 2018
# MugenNimbus
# ----------------
# 5
# Instant Ink Full Stack Web Developer: Blog Search jobs Keyword CategorySelectAdministrationBusiness PlanningCorpora… https://t.co/ygGygq33Vn
# Thu Jul 12 17:55:08 +0000 2018
# SanDiego_IT
# ----------------
# 6
# ...

# %%
#count=3, until='2012-01-01'
query = twitter.search.tweets(q = "coffee", count=10000)
print(type(query))
# Out:
# <class 'twitter.api.TwitterDictResponse'>

# %%
test2 = query['statuses']

# %%
data_search = {}
counter=1
for i in test2:
    print(counter)
    data_search['text'] = i['text']
    data_search['date'] = i['created_at']
    data_search['user'] = i['user']['screen_name']
    print(i['text'])
    print(i['created_at'])
    print(i['user']['screen_name'])
    print('----------------')
    counter +=1
# Out:
# 1
# RT @KatieHTweeets: Just overheard a guy call his wife at Starbucks and ask “do you want your ice coffee or are you still being a bitch”. An…
# Fri Jul 13 02:39:06 +0000 2018
# dandohe
# ----------------
# 2
# 本気で疲れてる時って何にも心が動かないからなぁ
# Fri Jul 13 02:39:06 +0000 2018
# coffee_junkie46
# ----------------
# 3
# @Coffee_Boss117 夏野菜カレーか
# Fri Jul 13 02:39:05 +0000 2018
# fox_kokona
# ----------------
# 4
# I like my coffee like i like my woman, I don't like coffee
# Fri Jul 13 02:39:03 +0000 2018
# gaboeltrejo
# ----------------
# 5
# RT @cafeforesta3: .
# 期間限定の白桃ソーダ🍑
# .
# 白桃の果肉がたっぷり！！
# のどごし爽やかな女性スタッフおすすめドリンクです🍹
# .
# #cafeforesta #cafe #coffee #latte #espresso #coldbrew  #specialt…
# Fri Jul 13 02:39:02 +0000 2018
# momozorori
# ----------------
# 6
# @dope_yoongi i do drink some before work but i find that a cup doesnt last me for a day); but ur idea sounds like a… https://t.co/QNN5fS1GS7
# Fri Jul 13 02:39:02 +0000 2018
# banqtansope
# ----------------
# 7
# ...

# %%
#-----------------------------------------------------------------------
# load our API credentials
#-----------------------------------------------------------------------
import sys
sys.path.append(".")
import config

#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(auth = OAuth(config.access_key,
                  config.access_secret,
                  config.consumer_key,
                  config.consumer_secret))

#-----------------------------------------------------------------------
# perform a basic search 
# Twitter API docs:
# https://dev.twitter.com/rest/reference/get/search/tweets
#-----------------------------------------------------------------------
query = twitter.search.tweets(q = "lazy dog")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-228-ef66f9f9b6ed> in <module>()
#       9 # create twitter API object
#      10 #-----------------------------------------------------------------------
# ---> 11 twitter = Twitter(auth = OAuth(config.access_key,
#      12                   config.access_secret,
#      13                   config.consumer_key,
#
# AttributeError: module 'config' has no attribute 'access_key'
