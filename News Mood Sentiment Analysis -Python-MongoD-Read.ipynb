# %% [markdown]
# ### News Mood Sentiment Analysis
#
# #### By: Naser Erwemi
#
# https://www.linkedin.com/in/aerwemi/
#
# https://github.com/aerwemi

# %% [markdown]
# ## Background
#
# __Twitter__ has become a wildly sprawling jungle of information&mdash;140 characters at a time. Somewhere between 350 million and 500 million tweets are estimated to be sent out _per day_. With such an explosion of data, on Twitter and elsewhere, it becomes more important than ever to tame it in some way, to concisely capture the essence of the data.
#
# ## News Mood
#
# A python script to perform sentiment analysis of the Twitter activity of various news outlets, and to present your findings visually.
#
# Your final output should provide a visualized summary of the sentiments expressed in Tweets sent out by the following news organizations: __BBC, CBS, CNN, Fox, New York Times and
# The Washington Post__.
#
#
#
# The first plot will be and/or feature the following:
#
# * Be a scatter plot of sentiments of the last __100__ tweets sent out by each news organization, ranging from -1.0 to 1.0, where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# * Each plot point will reflect the _compound_ sentiment of a tweet.
# * Sort each plot point by its relative timestamp.
#
# The second plot will be a bar plot visualizing the _overall_ sentiments of the last 100 tweets from each organization. For this plot, you will again aggregate the compound sentiments analyzed by VADER.
#
# The tools of the trade you will need for your task as a data analyst include the following: tweepy, pandas, matplotlib, seaborn, textblob, and VADER.
#
# Included analysis:
#
# * Pull last 100 tweets from each outlet.
# * Sentiment analysis with the compound, positive, neutral, and negative scoring for each tweet.
# * A DataFrame the tweet's source account, its text, its date, and its compound, positive, neutral, and negative sentiment scores.
# * DataFrame into a CSV file.
# * PNG images for each plot.

# %% [markdown]
# # Studay Summary and Conclusions
#
#
# BBC and CBS has much fewer tweets and followers than other outlets.
#
# BBC and CBS tweets are more positive than other outlets. Tweets normally distributed for most of the news outlets with most of the tweets are neutral scores.
#
# BBC and CBS have similar polarity distribution.
#
# CNN, Fox, New York Times and The Washington Post have similar polarity distribution.
#
# CNN, Fox, NY time and WP are more negative than BBC can CBS with distribution slightly skewed to the negative side.
#
# Time series analysis may help understand the frequency of tweets Where BBC and CBS tweets less than other outlets.

# %% [markdown]
# # Read MongoDB

# %%
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Declare the database
db = client.NewsMood2
collection = db.NewsMood2

# %%
# Verify results:

tweets = collection.find()

# %%
NewsMoodDb=[]
for thisTweet in tweets:
    NewsMoodDb.append(thisTweet)

# %%
len(NewsMoodDb)
# Out:
# 2279

# %%
NewsMoodDb[0]
# Out:
# {'Date': 'Fri Jul 13 17:02:05 +0000 2018',
#  'NewsSource': 'BBC',
#  'Text': 'The best time to plant a tree was 20 years ago. The second best time is now. 🌳\n\nEight Chinese proverbs to help with… https://t.co/zqSO489S8G',
#  '_id': ObjectId('5b48dfa33a8902249c09d72c'),
#  'comScore': 0.9022,
#  'negScore': 0.0,
#  'neuScore': 0.643,
#  'posScore': 0.357}

# %%
import pandas as pd 
pd.DataFrame(NewsMoodDb)
# Out:
#                                 Date      NewsSource  \
# 0     Fri Jul 13 17:02:05 +0000 2018             BBC
# 2257  "All a little misdirection": Inside Trump’s so...
# 2258  The Russian pipeline to Germany that Trump is ...
# 2259  Analysis: Brett Kavanaugh, Trump and what the ...
# 2260  The Cybersecurity 202: Privacy advocates blast...
# 2261  The Daily 202: Leaked recordings of Ga. govern...
# 2262  Trump seeks to reassure anxious farmers being ...
# 2263  Ocasio-Cortez wins a second congressional prim...
# 2264  Mighty England, a World Cup Cinderella? The sh...
# 2265  California will face a terrible choice: Save c...
# 2266  New York organ collection agency, nation’s sec...
# 2267  Watch live as world leaders attend the NATO su...
# 2268  Days after Scott Pruitt resigned, several top ...
# 2269  Thai soccer coach meditated with boys to calm ...
# 2270  "The Handmaid’s Tale" Season 2 finale: The mos...
# 2271  From effigies to egging: The British have a lo...
# 2272  Keep your heads down, U.S. embassy warns Ameri...
# 2273  Trump retweets a convicted forger welcoming hi...
# 2274  Woman harassed for wearing Puerto Rico shirt "...
# 2275  Ex-Apple engineer arrested on his way to China...
# 2276  Fact Checker: Does Brett Kavanaugh think the p...
# 2277  As Israeli bulldozers circle, a tiny village t...
# 2278  Pence: I want Roe v. Wade overturned, "but I h...
#
#                            _id  comScore  negScore  neuScore  posScore
# 0     5b48dfa33a8902249c09d72c    0.9022     0.000     0.643     0.357
# 1     5b48dfa43a8902249c09d72d   -0.0516     0.062     0.938     0.000
# 2     5b48dfa53a8902249c09d72e    0.0000     0.000     1.000     0.000
# 3     5b48dfa63a8902249c09d72f    0.0382     0.000     0.943     0.057
# 4     5b48dfa73a8902249c09d730   -0.7579     0.427     0.418     0.155
# 5     5b48dfa83a8902249c09d731    0.3182     0.000     0.881     0.119
# 6     5b48dfa93a8902249c09d732    0.0000     0.000     1.000     0.000
# 7     5b48dfaa3a8902249c09d733    0.0000     0.000     1.000     0.000
# 8     5b48dfab3a8902249c09d734    0.0000     0.000     1.000     0.000
# 9     5b48dfac3a8902249c09d735    0.1779     0.000     0.909     0.091
# 10    5b48dfad3a8902249c09d736    0.0000     0.000     1.000     0.000
# 11    5b48dfae3a8902249c09d737   -0.0772     0.071     0.929     0.000
# 12    5b48dfaf3a8902249c09d738    0.6249     0.000     0.785     0.215
# 13    5b48dfb03a8902249c09d739   -0.0258     0.215     0.539     0.246
# 14    5b48dfb13a8902249c09d73a    0.0000     0.000     1.000     0.000
# 15    5b48dfb23a8902249c09d73b    0.6597     0.178     0.512     0.310
# 16    5b48dfb33a8902249c09d73c    0.4404     0.000     0.854     0.146
# 17    5b48dfb43a8902249c09d73d    0.0000     0.000     1.000     0.000
# 18    5b48dfb53a8902249c09d73e   -0.3182     0.087     0.913     0.000
# 19    5b48dfb63a8902249c09d73f    0.0000     0.000     1.000     0.000
# 20    5b48dfb93a8902249c09d740    0.0000     0.000     1.000     0.000
# 21    5b48dfba3a8902249c09d741   -0.1788     0.182     0.733     0.086
# 22    5b48dfbb3a8902249c09d742    0.0000     0.000     1.000     0.000
